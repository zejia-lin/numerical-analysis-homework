# %%
import sympy as sp

# %%
c1, c2, c3, c4, c5, c6 = sp.symbols('c1 c2 c3 c4 c5 c6')
alpha = sp.symbols('alpha')
e = sp.symbols('e')
x = alpha + e
e1 = e
e2 = e ** 2
e3 = e ** 3
e4 = e ** 4
e5 = e ** 5
e6 = e ** 6

# %%
def taylor_1plus_theta(the, order):
    inv = 1 / (1 + the)
    return inv.series(e, 0, order)

def getO(the, order):
    return taylor_1plus_theta(the, order) - taylor_1plus_theta(the, order).removeO()

o3 = getO(e, 3)
o4 = getO(e, 4)
o6 = getO(e, 6)
o7 = getO(e, 7)
o6, o7
# Out:
# (O(e**6), O(e**7))

# %%
def df(err, expand=False):
    eee = lambda x: x
    if expand:
        eee = sp.expand
    return eee(1 + 2*c2*err + 3*c3*err**2 + 4*c4*err**3 + 5*c5*err**4 + 6*c6*err**5 + o6)


def f(err):
    return c1*err + c2*err**2 + c3*err**3 + c4*err**4 + c5*err**5 + c6*err**6 + o7


def taylor_inv(fenmu, order):
    inv = 1 / fenmu
    return 1 / inv.series(e, 0, order)

# %%
fx = f(e)
fx
# Out:
# c6*e**6 + c5*e**5 + c4*e**4 + c3*e**3 + c2*e**2 + c1*e + O(e**7)

# %%
dx = df(e)
dx
# Out:
# 1 + 6*c6*e**5 + 5*c5*e**4 + 4*c4*e**3 + 3*c3*e**2 + 2*c2*e + O(e**6)

# %%
1 / taylor_inv(df(e), 6)
# Out:
# 1 + e**2*(4*c2**2 - 3*c3) + e**3*(-8*c2**3 + 12*c2*c3 - 4*c4) + e**4*(16*c2**4 - 36*c2**2*c3 + 16*c2*c4 + 9*c3**2 - 5*c5) + e**5*(-32*c2**5 + 96*c2**3*c3 - 16*c2**2*c4 - 36*c2*c3**2 + 20*c2*c5 - 2*c2*(16*c2*c4 + 9*c3**2) + 24*c3*c4 - 6*c6) - 2*c2*e + O(e**6)

# %%
fx_div_dx = sp.collect(sp.expand(fx / taylor_inv(df(e), 6)), e)
fx_div_dx
# Out:
# e**2*(-2*c1*c2 + c2) + e**3*(4*c1*c2**2 - 3*c1*c3 - 2*c2**2 + c3) + e**4*(-8*c1*c2**3 + 12*c1*c2*c3 - 4*c1*c4 + 4*c2**3 - 5*c2*c3 + c4) + e**5*(16*c1*c2**4 - 36*c1*c2**2*c3 + 16*c1*c2*c4 + 9*c1*c3**2 - 5*c1*c5 - 8*c2**4 + 16*c2**2*c3 - 6*c2*c4 - 3*c3**2 + c5) + e**6*(-32*c1*c2**5 + 96*c1*c2**3*c3 - 48*c1*c2**2*c4 - 54*c1*c2*c3**2 + 20*c1*c2*c5 + 24*c1*c3*c4 - 6*c1*c6 + 16*c2**5 - 44*c2**3*c3 + 20*c2**2*c4 + 21*c2*c3**2 - 7*c2*c5 - 7*c3*c4 + c6) + c1*e + O(e**7)

# %%
y = x - fx_div_dx
y
# Out:
# e - e**2*(-2*c1*c2 + c2) - e**3*(4*c1*c2**2 - 3*c1*c3 - 2*c2**2 + c3) - e**4*(-8*c1*c2**3 + 12*c1*c2*c3 - 4*c1*c4 + 4*c2**3 - 5*c2*c3 + c4) - e**5*(16*c1*c2**4 - 36*c1*c2**2*c3 + 16*c1*c2*c4 + 9*c1*c3**2 - 5*c1*c5 - 8*c2**4 + 16*c2**2*c3 - 6*c2*c4 - 3*c3**2 + c5) - e**6*(-32*c1*c2**5 + 96*c1*c2**3*c3 - 48*c1*c2**2*c4 - 54*c1*c2*c3**2 + 20*c1*c2*c5 + 24*c1*c3*c4 - 6*c1*c6 + 16*c2**5 - 44*c2**3*c3 + 20*c2**2*c4 + 21*c2*c3**2 - 7*c2*c5 - 7*c3*c4 + c6) - c1*e + alpha + O(e**7)

# %%
dy = df(y - alpha, True)

# %%
sp.collect(dy, e)
# Out:
# 1 + e*(-2*c1*c2 + 2*c2) + e**2*(3*c1**2*c3 + 4*c1*c2**2 - 6*c1*c3 - 2*c2**2 + 3*c3) + e**3*(-4*c1**3*c4 - 12*c1**2*c2*c3 + 12*c1**2*c4 - 8*c1*c2**3 + 24*c1*c2*c3 - 12*c1*c4 + 4*c2**3 - 8*c2*c3 + 4*c4) + e**4*(5*c1**4*c5 + 24*c1**3*c2*c4 - 20*c1**3*c5 + 36*c1**2*c2**2*c3 - 60*c1**2*c2*c4 - 18*c1**2*c3**2 + 30*c1**2*c5 + 16*c1*c2**4 - 72*c1*c2**2*c3 + 56*c1*c2*c4 + 24*c1*c3**2 - 20*c1*c5 - 8*c2**4 + 25*c2**2*c3 - 14*c2*c4 - 6*c3**2 + 5*c5) + e**5*(-6*c1**5*c6 - 40*c1**4*c2*c5 + 30*c1**4*c6 - 96*c1**3*c2**2*c4 + 140*c1**3*c2*c5 + 36*c1**3*c3*c4 - 60*c1**3*c6 - 96*c1**2*c2**3*c3 + 216*c1**2*c2**2*c4 + 108*c1**2*c2*c3**2 - 180*c1**2*c2*c5 - 108*c1**2*c3*c4 + 60*c1**2*c6 - 32*c1*c2**5 + 192*c1*c2**3*c3 - 188*c1*c2**2*c4 - 150*c1*c2*c3**2 + 110*c1*c2*c5 + 90*c1*c3*c4 - 30*c1*c6 + 16*c2**5 - 68*c2**3*c3 + 48*c2**2*c4 + 42*c2*c3**2 - 22*c2*c5 - 18*c3*c4 + 6*c6) + O(e**6)

# %%
z = x - 2 * fx / taylor_inv(dx + dy, 6)
sp.collect(sp.expand(z), e)
# Out:
# e*(1 - c1) + e**2*(-c1**2*c2 + 2*c1*c2 - c2) + e**3*(-c1**3*c2**2 + 3*c1**3*c3/2 + 6*c1**2*c2**2 - 3*c1**2*c3 - 6*c1*c2**2 + 3*c1*c3 + 2*c2**2 - c3) + e**4*(-c1**4*c2**3 + 3*c1**4*c2*c3 - 2*c1**4*c4 + 10*c1**3*c2**3 - 18*c1**3*c2*c3 + 6*c1**3*c4 - 27*c1**2*c2**3 + 63*c1**2*c2*c3/2 - 6*c1**2*c4 + 20*c1*c2**3 - 20*c1*c2*c3 + 4*c1*c4 - 5*c2**3 + 5*c2*c3 - c4) + e**5*(-c1**5*c2**4 + 9*c1**5*c2**2*c3/2 - 4*c1**5*c2*c4 - 9*c1**5*c3**2/4 + 5*c1**5*c5/2 + 14*c1**4*c2**4 - 45*c1**4*c2**2*c3 + 32*c1**4*c2*c4 + 9*c1**4*c3**2 - 10*c1**4*c5 - 64*c1**3*c2**4 + 147*c1**3*c2**2*c3 - 68*c1**3*c2*c4 - 27*c1**3*c3**2 + 15*c1**3*c5 + 110*c1**2*c2**4 - 201*c1**2*c2**2*c3 + 66*c1**2*c2*c4 + 63*c1**2*c3**2/2 - 10*c1**2*c5 - 67*c1*c2**4 + 213*c1*c2**2*c3/2 - 30*c1*c2*c4 - 15*c1*c3**2 + 5*c1*c5 + 14*c2**4 - 21*c2**2*c3 + 6*c2*c4 + 3*c3**2 - c5) + e**6*(-c1**6*c2**5 + 6*c1**6*c2**3*c3 - 6*c1**6*c2**2*c4 - 27*c1**6*c2*c3**2/4 + 5*c1**6*c2*c5 + 6*c1**6*c3*c4 - 3*c1**6*c6 + 18*c1**5*c2**5 - 84*c1**5*c2**3*c3 + 74*c1**5*c2**2*c4 + 117*c1**5*c2*c3**2/2 - 50*c1**5*c2*c5 - 30*c1**5*c3*c4 + 15*c1**5*c6 - 117*c1**4*c2**5 + 843*c1**4*c2**3*c3/2 - 302*c1**4*c2**2*c4 - 801*c1**4*c2*c3**2/4 + 285*c1**4*c2*c5/2 + 84*c1**4*c3*c4 - 30*c1**4*c6 + 336*c1**3*c2**5 - 964*c1**3*c2**3*c3 + 508*c1**3*c2**2*c4 + 408*c1**3*c2*c3**2 - 180*c1**3*c2*c5 - 140*c1**3*c3*c4 + 30*c1**3*c6 - 426*c1**2*c2**5 + 1053*c1**2*c2**3*c3 - 435*c1**2*c2**2*c4 - 405*c1**2*c2*c3**2 + 120*c1**2*c2*c5 + 225*c1**2*c3*c4/2 - 15*c1**2*c6 + 222*c1*c2**5 - 492*c1*c2**3*c3 + 174*c1*c2**2*c4 + 171*c1*c2*c3**2 - 42*c1*c2*c5 - 42*c1*c3*c4 + 6*c1*c6 - 41*c2**5 + 169*c2**3*c3/2 - 28*c2**2*c4 - 28*c2*c3**2 + 7*c2*c5 + 7*c3*c4 - c6) + alpha + O(e**7)

# %%
fz = f(z - alpha)

# %%
newx = z - 2 * fz / taylor_inv(dx + dy, 6)

# %%
newx
# Out:
# alpha + e - (1/2 + e*(c1*c2/2 - c2) + e**2*(-3*c1**2*c3/4 - c1*c2**2 + 3*c1*c3/2 + c2**2/2 - 3*c3/2 + (-c1*c2 + 2*c2)**2/2) + e**3*(c1**3*c4 + 3*c1**2*c2*c3 - 3*c1**2*c4 + 2*c1*c2**3 - 6*c1*c2*c3 + 3*c1*c4 - c2**3 + 2*c2*c3 - 2*c4 - (-c1*c2 + 2*c2)**3/2 + (-c1*c2 + 2*c2)*(3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)) + e**4*(-5*c1**4*c5/4 - 6*c1**3*c2*c4 + 5*c1**3*c5 - 9*c1**2*c2**2*c3 + 15*c1**2*c2*c4 + 9*c1**2*c3**2/2 - 15*c1**2*c5/2 - 4*c1*c2**4 + 18*c1*c2**2*c3 - 14*c1*c2*c4 - 6*c1*c3**2 + 5*c1*c5 + 2*c2**4 - 25*c2**2*c3/4 + 7*c2*c4/2 + 3*c3**2/2 - 5*c5/2 + (-c1*c2 + 2*c2)**4/2 - 3*(-c1*c2 + 2*c2)**2*(3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)/2 + (-c1*c2 + 2*c2)*(-2*c1**3*c4 - 6*c1**2*c2*c3 + 6*c1**2*c4 - 4*c1*c2**3 + 12*c1*c2*c3 - 6*c1*c4 + 2*c2**3 - 4*c2*c3 + 4*c4) + (3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)**2/2) + e**5*(3*c1**5*c6/2 + 10*c1**4*c2*c5 - 15*c1**4*c6/2 + 24*c1**3*c2**2*c4 - 35*c1**3*c2*c5 - 9*c1**3*c3*c4 + 15*c1**3*c6 + 24*c1**2*c2**3*c3 - 54*c1**2*c2**2*c4 - 27*c1**2*c2*c3**2 + 45*c1**2*c2*c5 + 27*c1**2*c3*c4 - 15*c1**2*c6 + 8*c1*c2**5 - 48*c1*c2**3*c3 + 47*c1*c2**2*c4 + 75*c1*c2*c3**2/2 - 55*c1*c2*c5/2 - 45*c1*c3*c4/2 + 15*c1*c6/2 - 4*c2**5 + 17*c2**3*c3 - 12*c2**2*c4 - 21*c2*c3**2/2 + 11*c2*c5/2 + 9*c3*c4/2 - 3*c6 - (-c1*c2 + 2*c2)**5/2 + 2*(-c1*c2 + 2*c2)**3*(3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3) - (-c1*c2 + 2*c2)**2*(-2*c1**3*c4 - 6*c1**2*c2*c3 + 6*c1**2*c4 - 4*c1*c2**3 + 12*c1*c2*c3 - 6*c1*c4 + 2*c2**3 - 4*c2*c3 + 4*c4)/2 - (-c1*c2 + 2*c2)*(2*(-c1*c2 + 2*c2)*(-2*c1**3*c4 - 6*c1**2*c2*c3 + 6*c1**2*c4 - 4*c1*c2**3 + 12*c1*c2*c3 - 6*c1*c4 + 2*c2**3 - 4*c2*c3 + 4*c4) + (3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)**2)/2 - (-c1*c2 + 2*c2)*(3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)**2 + (-c1*c2 + 2*c2)*(5*c1**4*c5/2 + 12*c1**3*c2*c4 - 10*c1**3*c5 + 18*c1**2*c2**2*c3 - 30*c1**2*c2*c4 - 9*c1**2*c3**2 + 15*c1**2*c5 + 8*c1*c2**4 - 36*c1*c2**2*c3 + 28*c1*c2*c4 + 12*c1*c3**2 - 10*c1*c5 - 4*c2**4 + 25*c2**2*c3/2 - 7*c2*c4 - 3*c3**2 + 5*c5) + (3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)*(-2*c1**3*c4 - 6*c1**2*c2*c3 + 6*c1**2*c4 - 4*c1*c2**3 + 12*c1*c2*c3 - 6*c1*c4 + 2*c2**3 - 4*c2*c3 + 4*c4)) + O(e**6))*(2*c6*e**6 + 2*c5*e**5 + 2*c4*e**4 + 2*c3*e**3 + 2*c2*e**2 + 2*c1*e + O(e**7)) - (1/2 + e*(c1*c2/2 - c2) + e**2*(-3*c1**2*c3/4 - c1*c2**2 + 3*c1*c3/2 + c2**2/2 - 3*c3/2 + (-c1*c2 + 2*c2)**2/2) + e**3*(c1**3*c4 + 3*c1**2*c2*c3 - 3*c1**2*c4 + 2*c1*c2**3 - 6*c1*c2*c3 + 3*c1*c4 - c2**3 + 2*c2*c3 - 2*c4 - (-c1*c2 + 2*c2)**3/2 + (-c1*c2 + 2*c2)*(3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)) + e**4*(-5*c1**4*c5/4 - 6*c1**3*c2*c4 + 5*c1**3*c5 - 9*c1**2*c2**2*c3 + 15*c1**2*c2*c4 + 9*c1**2*c3**2/2 - 15*c1**2*c5/2 - 4*c1*c2**4 + 18*c1*c2**2*c3 - 14*c1*c2*c4 - 6*c1*c3**2 + 5*c1*c5 + 2*c2**4 - 25*c2**2*c3/4 + 7*c2*c4/2 + 3*c3**2/2 - 5*c5/2 + (-c1*c2 + 2*c2)**4/2 - 3*(-c1*c2 + 2*c2)**2*(3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)/2 + (-c1*c2 + 2*c2)*(-2*c1**3*c4 - 6*c1**2*c2*c3 + 6*c1**2*c4 - 4*c1*c2**3 + 12*c1*c2*c3 - 6*c1*c4 + 2*c2**3 - 4*c2*c3 + 4*c4) + (3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3)**2/2) + e**5*(3*c1**5*c6/2 + 10*c1**4*c2*c5 - 15*c1**4*c6/2 + 24*c1**3*c2**2*c4 - 35*c1**3*c2*c5 - 9*c1**3*c3*c4 + 15*c1**3*c6 + 24*c1**2*c2**3*c3 - 54*c1**2*c2**2*c4 - 27*c1**2*c2*c3**2 + 45*c1**2*c2*c5 + 27*c1**2*c3*c4 - 15*c1**2*c6 + 8*c1*c2**5 - 48*c1*c2**3*c3 + 47*c1*c2**2*c4 + 75*c1*c2*c3**2/2 - 55*c1*c2*c5/2 - 45*c1*c3*c4/2 + 15*c1*c6/2 - 4*c2**5 + 17*c2**3*c3 - 12*c2**2*c4 - 21*c2*c3**2/2 + 11*c2*c5/2 + 9*c3*c4/2 - 3*c6 - (-c1*c2 + 2*c2)**5/2 + 2*(-c1*c2 + 2*c2)**3*(3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3*c3) - (-c1*c2 + 2*c2)**2*(-2*c1**3*c4 - 6*c1**2*c2*c3 + 6*c1**2*c4 - 4*c1*c2**3 + 12*c1*c2*c3 - 6*c1*c4 + 2*c2**3 - 4*c2*c3 + 4*c4)/2 - (-c1*c2 + 2*c2)*(2*(-c1*c2 + 2*c2)*(-2*c1**3*c4 - 6*c1**2*c2*c3 + 6*c1**2*c4 - 4*c1*c2**3 + 12*c1*c2*c3 - 6*c1*c4 + 2*c2**3 - 4*c2*c3 + 4*c4) + (3*c1**2*c3/2 + 2*c1*c2**2 - 3*c1*c3 - c2**2 + 3* ...
